# %%
# Import modules
from sqlalchemy import create_engine
import pymysql
import pandas as pd

# helpers
# %matplotlib inline

# %%
# Connect to the sql data base
db_connection_str = 'mysql+pymysql://deepanalytics:Sqltask1234!@34.73.222.197/deepanalytics'
db_connection = create_engine(db_connection_str)
# Set df equal to the sql data
df = pd.read_sql('SELECT * FROM credit', con=db_connection)
df.to_csv("credit1.csv", index=False)

# %%
# Import the data set
df = pd.read_csv('credit1.csv')

# %%
# Make Row 1 the header row, since it is much easier to read
df.columns = df.iloc[0]
df = df[1:]
df.head()
# Out:
# 0 ID LIMIT_BAL     SEX   EDUCATION MARRIAGE AGE PAY_0 PAY_2 PAY_3 PAY_4  ...  \
# 1  1     20000  female  university        1  24     2     2    -1    -1  ...
# 2  2    120000  female  university        2  26    -1     2     0     0  ...
# 3  3     90000  female  university        2  34     0     0     0     0  ...
# 4  4     50000  female  university        1  37     0     0     0     0  ...
# 5  5     50000    male  university        1  57    -1     0    -1     0  ...
#
# 0 BILL_AMT4 BILL_AMT5 BILL_AMT6 PAY_AMT1 PAY_AMT2 PAY_AMT3 PAY_AMT4 PAY_AMT5  \
# 1         0         0         0        0      689        0        0        0
# 2      3272      3455      3261        0     1000     1000     1000        0
# 3     14331     14948     15549     1518     1500     1000     1000     1000
# 4     28314     28959     29547     2000     2019     1200     1100     1069
# 5     20940     19146     19131     2000    36681    10000     9000      689
#
# 0 PAY_AMT6 default payment next month
# ...

# %%
# None of the features are numeric, and need to be changed
# ID has a null object
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30203 entries, 1 to 30203
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30202 non-null  object
#  1   LIMIT_BAL                   30203 non-null  object
#  2   SEX                         30203 non-null  object
#  3   EDUCATION                   30203 non-null  object
#  4   MARRIAGE                    30203 non-null  object
#  5   AGE                         30203 non-null  object
#  6   PAY_0                       30203 non-null  object
#  7   PAY_2                       30203 non-null  object
#  8   PAY_3                       30203 non-null  object
#  9   PAY_4                       30203 non-null  object
#  10  PAY_5                       30203 non-null  object
#  11  PAY_6                       30203 non-null  object
#  12  BILL_AMT1                   30203 non-null  object
# ...

# %%
# Rows 202 and 203 are copies of the Header Rows
# df.head(205)
print(df.loc[200:208, :])
# Out:
# 0     ID  LIMIT_BAL     SEX        EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  \
# 200  200      30000  female      high school         2   22      1      2
# 201  201     180000  female  graduate school         1   38     -2     -2
# 202  NaN         X1      X2               X3        X4   X5     X6     X7
# 203   ID  LIMIT_BAL     SEX        EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2
# 204    1      20000  female       university         1   24      2      2
# 205    2     120000  female       university         2   26     -1      2
# 206    3      90000  female       university         2   34      0      0
# 207    4      50000  female       university         1   37      0      0
# 208    5      50000    male       university         1   57     -1      0
#
# 0    PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 200      2      0  ...      29836       1630          0      1000        85
# ...

# %%
# Drops the unneeded Header rows
df=df.drop(df.index[[201,202]])

# %%
# Check that the header rows were dropped
print(df.loc[200:208, :])
# Out:
# 0     ID LIMIT_BAL     SEX        EDUCATION MARRIAGE AGE PAY_0 PAY_2 PAY_3  \
# 200  200     30000  female      high school        2  22     1     2     2
# 201  201    180000  female  graduate school        1  38    -2    -2    -2
# 204    1     20000  female       university        1  24     2     2    -1
# 205    2    120000  female       university        2  26    -1     2     0
# 206    3     90000  female       university        2  34     0     0     0
# 207    4     50000  female       university        1  37     0     0     0
# 208    5     50000    male       university        1  57    -1     0    -1
#
# 0   PAY_4  ... BILL_AMT4 BILL_AMT5 BILL_AMT6 PAY_AMT1 PAY_AMT2 PAY_AMT3  \
# 200     0  ...     29836      1630         0     1000       85     1714
# 201    -2  ...         0         0         0        0        0        0
# 204    -1  ...         0         0         0        0      689        0
# 205     0  ...      3272      3455      3261        0     1000     1000
# ...

# %%
# Drop duplicate records
# Corrected the null ID
df=df.drop_duplicates()
df.info()

# First 202 rows were duplicates - 200 rows of data and 2 header rows were duplicated
# Every feature is an object, have to convert to numeric and string
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30000 entries, 1 to 30203
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  object
#  1   LIMIT_BAL                   30000 non-null  object
#  2   SEX                         30000 non-null  object
#  3   EDUCATION                   30000 non-null  object
#  4   MARRIAGE                    30000 non-null  object
#  5   AGE                         30000 non-null  object
#  6   PAY_0                       30000 non-null  object
#  7   PAY_2                       30000 non-null  object
#  8   PAY_3                       30000 non-null  object
#  9   PAY_4                       30000 non-null  object
#  10  PAY_5                       30000 non-null  object
#  11  PAY_6                       30000 non-null  object
#  12  BILL_AMT1                   30000 non-null  object
# ...

# %%
# Save the cleaned data set
df.to_csv("credit1.csv", index=False)
# Read the updated data set
df = pd.read_csv('credit1.csv')

# %%
# Check for null records
print(df.isnull().sum())
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
# Convert columns to numeric, where possible
# Sex, Education and default payment next month are text, and objects
df = df.apply(pd.to_numeric, errors='ignore')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  object
#  3   EDUCATION                   30000 non-null  object
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
# Save the cleaned data set
df.to_csv("credit1.csv", index=False)
# Read the updated data set
df = pd.read_csv('credit1.csv')

# %%
# Basic statistical info on the data
df.describe().applymap('{:,.2f}'.format)
# Out:
#               ID     LIMIT_BAL   MARRIAGE        AGE      PAY_0      PAY_2  \
# count  30,000.00     30,000.00  30,000.00  30,000.00  30,000.00  30,000.00
# mean   15,000.50    167,484.32       1.55      35.49      -0.02      -0.13
# std     8,660.40    129,747.66       0.52       9.22       1.12       1.20
# min         1.00     10,000.00       0.00      21.00      -2.00      -2.00
# 25%     7,500.75     50,000.00       1.00      28.00      -1.00      -1.00
# 50%    15,000.50    140,000.00       2.00      34.00       0.00       0.00
# 75%    22,500.25    240,000.00       2.00      41.00       0.00       0.00
# max    30,000.00  1,000,000.00       3.00      79.00       8.00       8.00
#
#            PAY_3      PAY_4      PAY_5      PAY_6  ...     BILL_AMT3  \
# count  30,000.00  30,000.00  30,000.00  30,000.00  ...     30,000.00
# mean       -0.17      -0.22      -0.27      -0.29  ...     47,013.15
# std         1.20       1.17       1.13       1.15  ...     69,349.39
# ...

# %%
# Basic data correlation information
corr_mat = df.corr().round(3)
print(corr_mat)
# Out:
#               ID  LIMIT_BAL  MARRIAGE    AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# ID         1.000      0.026    -0.029  0.019 -0.031 -0.011 -0.018 -0.003
# LIMIT_BAL  0.026      1.000    -0.108  0.145 -0.271 -0.296 -0.286 -0.267
# MARRIAGE  -0.029     -0.108     1.000 -0.414  0.020  0.024  0.033  0.033
# AGE        0.019      0.145    -0.414  1.000 -0.039 -0.050 -0.053 -0.050
# PAY_0     -0.031     -0.271     0.020 -0.039  1.000  0.672  0.574  0.539
# PAY_2     -0.011     -0.296     0.024 -0.050  0.672  1.000  0.767  0.662
# PAY_3     -0.018     -0.286     0.033 -0.053  0.574  0.767  1.000  0.777
# PAY_4     -0.003     -0.267     0.033 -0.050  0.539  0.662  0.777  1.000
# PAY_5     -0.022     -0.249     0.036 -0.054  0.509  0.623  0.687  0.820
# PAY_6     -0.020     -0.235     0.034 -0.049  0.475  0.576  0.633  0.716
# BILL_AMT1  0.019      0.285    -0.023  0.056  0.187  0.235  0.208  0.203
# BILL_AMT2  0.018      0.278    -0.022  0.054  0.190  0.235  0.237  0.226
# ...

# %%
# Covariance information
cov_mat = df.cov().round(2)
print(cov_mat)
# Out:
#                     ID     LIMIT_BAL  MARRIAGE        AGE     PAY_0     PAY_2  \
# ID         75002500.00  2.941664e+07   -131.45    1491.06   -297.57   -116.28
# LIMIT_BAL  29416640.92  1.683446e+10  -7323.67  173076.72 -39545.93 -46037.65
# MARRIAGE       -131.45 -7.323670e+03      0.27      -1.99      0.01      0.02
# AGE            1491.06  1.730767e+05     -1.99      84.97     -0.41     -0.55
# PAY_0          -297.57 -3.954593e+04      0.01      -0.41      1.26      0.90
# PAY_2          -116.28 -4.603765e+04      0.02      -0.55      0.90      1.43
# PAY_3          -191.69 -4.443225e+04      0.02      -0.59      0.77      1.10
# PAY_4           -27.69 -4.057181e+04      0.02      -0.54      0.71      0.93
# PAY_5          -217.86 -3.667056e+04      0.02      -0.56      0.65      0.84
# PAY_6          -201.88 -3.509308e+04      0.02      -0.52      0.61      0.79
# BILL_AMT1  12364465.39  2.727020e+09   -902.15   38172.93  15480.30  20706.61
# ...

# %%
df.head()
# Out:
#    ID  LIMIT_BAL     SEX   EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0   1      20000  female  university         1   24      2      2     -1
# 1   2     120000  female  university         2   26     -1      2      0
# 2   3      90000  female  university         2   34      0      0      0
# 3   4      50000  female  university         1   37      0      0      0
# 4   5      50000    male  university         1   57     -1      0     -1
#
#    PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -1  ...          0          0          0         0       689         0
# 1      0  ...       3272       3455       3261         0      1000      1000
# 2      0  ...      14331      14948      15549      1518      1500      1000
# 3      0  ...      28314      28959      29547      2000      2019      1200
# 4      0  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %% [markdown]
# mapping = {'male':1, 'female':2}
# df=df.replace({'SEX': mapping})

# %% [markdown]
# mapping = {'graduate school': 1, 'university': 2, 'high school': 3,'other':4}
# df=df.replace({'EDUCATION':mapping})

# %% [markdown]
# df=df.rename(columns={'default payment next month':'default'})

# %% [markdown]
# mapping = {'default':1, 'not default': 2}
# df=df.replace({'default':mapping})
# df.info()
